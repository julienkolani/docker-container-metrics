# %%
directories = [
    "accuweather-api",
    "api-manager",
    "chatbot_backoffice_admin",
    "chatbot_banking_backoffice_admin",
    "chatbot_partenaire_api_microfina",
    "currency-api",
    "d_pharmacy_pools_flutter_v2",
    "dac-intltel",
    "dac-mirror-api",
    "dac-otp",
    "dac_stats_front",
    "dacpaye-server",
    "dacpharmapro_saml_project",
    "delivery-admin-web-app",
    "delivery-api",
    "delivery-organisation-web-app-v2",
    "ebeez_api",
    "ebeez_dashboard",
    "f_pharma_admin_tg",
    "flooz-callback",
    "global-stat",
    "lonato-microservice-api",
    "new-tmoney-callback",
    "pharmacie-api",
    "pharmacie-webhook",
    "pharmacy_pools_auto_gen_api"
]

# Replace "_" with "-"
directories = [dir_name.replace('_', '-') for dir_name in directories]

# Generate Docker --mount options
for dir_name in directories:
    print(f'--mount=target=node_modules/.bin,type=cache,sharing=locked,id={dir_name} \\')
# Out:
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=accuweather-api \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=api-manager \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=chatbot-backoffice-admin \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=chatbot-banking-backoffice-admin \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=chatbot-partenaire-api-microfina \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=Currency-api \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=d-pharmacy-pools-flutter-v2 \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=dac-intltel \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=dac-mirror-api \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=dac-otp \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=dac-stats-front \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=dacpaye-server \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=dacpharmapro-saml-project \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=delivery-admin-web-app \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=delivery-api \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=delivery-organisation-web-app-v2 \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=ebeez-api \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=ebeez-dashboard \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=f-pharma-admin-tg \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=flooz-callback \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=global-stat \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=lonato-microservice-api \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=new-tmoney-callback \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=pharmacie-api \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=pharmacie-webhook \
# --mount=target=node_modules/.bin,type=cache,sharing=locked,id=pharmacy-pools-auto-gen-api \
